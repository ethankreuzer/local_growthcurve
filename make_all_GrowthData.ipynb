# %%
import pandas as pd
import numpy as np

# %% [markdown]
# GrowthCurve_allData.csv is the very first screen we did, with a ~700 cpd antimicrobial library from MedChem Express, and 2000 cpds from the IRIC library. Each was done in 1 replicate, but at 4 concentrations.

# %% [markdown]
# Enamine_endOD and Enamine_t6_t12 correspond to the second screen (of the Enamine antimicrobial library, 32,000 cpds). They both have the same information, but _t6_t12 includes the mid point measurement as well. This one was done in 2 replicates, but only at 1 concentration (50 μM).

# %% [markdown]
# Now, because we could only measure 1 concentration in the Enamine screen, we selected the most active compounds (254) out of it, and did another experiment where we took several time points and several concentrations, in 2 replicates. So Enamine_DR_growthcurves.csv is another experiment, but with a subset of the Enamine compounds. This experiment is part of the hit-validation pipeline required in drug development programs, it's a Dose-Response assay that helps you select candidate compounds by their potency. The MIC is one way of representing that potency, another commonly used is the IC50.

# %% [markdown]
# # df_GrowthCurve_allData

# %%
df_GrowthCurve_allData = pd.read_csv('/Users/ethankreuzer/Desktop/UdeM/MILA/GrowthCurve_allData.csv')
df_GrowthCurve_allData['MIC'].unique()

print(df_GrowthCurve_allData['Concentration'].unique())
print(df_GrowthCurve_allData['MIC'].unique())
# Out:
# [ 0.2  1.2 50.   7.9]
# ['DMSO' 'Inactive' '7.9' '50' '1.2' '0.2' 'Cipro' 'Fosfo']

# %% [markdown]
# Cipro and Fosfo are known anti biotics (Postive Control)
#
# DMSO is a negative control

# %%
df_GrowthCurve_allData = df_GrowthCurve_allData[['Well','Plate','ProductName','Concentration','MIC','Smiles',
                                                 't_0','t_2.08', 't_4.16', 't_6.24', 't_8.32', 't_10.4', 't_12.48']] #keep these columns

df_GrowthCurve_allData=df_GrowthCurve_allData.rename(columns={"Plate": "Plate_ID","MIC":"Control_Label","ProductName":"Compound"}) #rename to be consistent with other compounds

df_GrowthCurve_allData["Control_Label"] = df_GrowthCurve_allData["Control_Label"].apply(
    lambda x: 1 if x in ['Cipro', 'Fosfo'] else (-1 if x == 'DMSO' else 0)
)

df_GrowthCurve_allData
# Out:
#       Well Plate_ID                  Compound  Concentration  Control_Label  \
# 0      A01      546                      DMSO            0.2             -1
# 1      A02      546                      DMSO            0.2             -1
# 2      A03      546  Polyoxyethylene stearate            0.2              0
# 3      A04      546       Lefamulin (acetate)            0.2              0
# 4      A05      546       Cefodizime (sodium)            0.2              0
# ...    ...      ...                       ...            ...            ...
# 18427  P20      S10                      DMSO            7.9             -1
# 18428  P21      S10                      DMSO            7.9             -1
# 18429  P22      S10                      DMSO            7.9             -1
# 18430  P23      S10                      DMSO            7.9             -1
# 18431  P24      S10                      DMSO            7.9             -1
#
#                                                   Smiles  t_0    t_2.08  \
# 0                                                    NaN  0.0  0.281996
# 1                                                    NaN  0.0  0.288503
# 2            O=C(OCCO)CCCCCCCCCCCCCCCCC.[n].[n].[=].[10]  0.0  0.286334
# 3      CC(O)=O.C[C@@H]1C23[C@](C(CC3)=O)([H])C([C@H](...  0.0  0.262473
# 4      O=C(C(N12)=C(CSC3=NC(C)=C(CC(O[Na])=O)S3)CS[C@...  0.0  0.275488
# ...                                                  ...  ...       ...
# 18427                                                NaN  0.0  0.187970
# 18428                                                NaN  0.0  0.185464
# 18429                                                NaN  0.0  0.187970
# 18430                                                NaN  0.0  0.197995
# 18431                                                NaN  0.0  0.213033
#
#          t_4.16    t_6.24    t_8.32    t_10.4   t_12.48
# 0      0.570499  0.763557  0.872017  0.965293  1.041215
# 1      0.613883  0.778742  0.889371  0.978308  1.062907
# 2      0.587852  0.765727  0.889371  0.982646  1.043384
# 3      0.559653  0.737527  0.863341  0.950108  1.008677
# 4      0.924078  0.676790  0.685466  0.668113  0.672451
# ...         ...       ...       ...       ...       ...
# 18427  0.511278  0.736842  0.857143  0.924812  0.989975
# 18428  0.491228  0.736842  0.867168  0.937343  1.002506
# 18429  0.506266  0.741855  0.874687  0.942356  1.012531
# 18430  0.523810  0.761905  0.877193  0.932331  0.997494
# 18431  0.526316  0.736842  0.884712  0.947368  1.012531
#
# [18432 rows x 13 columns]

# %%
# Group by Compound and Concentration, then compute number of unique Wells and Plate_IDs
well_and_plate_consistency = (
    df_GrowthCurve_allData
    .groupby(['Compound', 'Concentration'])
    .agg(
        n_unique_wells=('Well', 'nunique'),
        n_unique_plates=('Plate_ID', 'nunique')
    )
)

# Filter to rows where there's more than one unique well
inconsistent_rows = well_and_plate_consistency[well_and_plate_consistency['n_unique_wells'] > 1]

# Display result
if inconsistent_rows.empty:
    print("All (Compound, Concentration) pairs are associated with a single Well and Plate_ID.")
else:
    print("The following (Compound, Concentration) pairs have inconsistencies:")
    print(inconsistent_rows)
# Out:
# The following (Compound, Concentration) pairs have inconsistencies:
#                              n_unique_wells  n_unique_plates
# Compound      Concentration
# Ciprofloxacin 0.2                        12                8
#               1.2                        12                8
#               7.9                        12                8
#               50.0                       12                8
# DMSO          0.2                       384               12
#               1.2                       384               12
#               7.9                       384               12
#               50.0                      384               12
# Fosfomycin    0.2                        12                7
#               1.2                        12                7
#               7.9                        12                7
#               50.0                       12                7

# %% [markdown]
# All the positive controls Fosfomycin get labeled as positive controls but for some reason not all Ciprofloxacin get labeled as positive contorls

# %% [markdown]
# # Control Growth Curves

# %%
df_control_growth_curves = pd.read_csv('Control_growthcurves.csv')
df_control_growth_curves
# Out:
#     Well  Concentration       Compound  Replicate       t_0    t_2.08  \
# 0     C3          50.00     Rifampicin          4  0.003157  0.001579
# 1     C4           0.20     Fosfomycin          1  0.000000  0.137337
# 2     C6           7.90  Ciprofloxacin          4  0.000000  0.012629
# 3     C8           3.13  Ciprofloxacin          5  0.000000  0.029993
# 4     C9          50.00   Trimethoprim          5  0.000000  0.033150
# ..   ...            ...            ...        ...       ...       ...
# 195  N16           7.90  Ciprofloxacin          2  0.000000  0.009472
# 196  N17           7.90           DMSO          5  0.000000  0.127866
# 197  N20           3.13     Rifampicin          6  0.000000  0.066301
# 198  N21          50.00           DMSO          2  0.000000  0.126287
# 199  N22          12.50     Rifampicin          6  0.000000  0.007893
#
#        t_4.16    t_6.24    t_8.32    t_10.4   t_12.48  \
# 0    0.001579  0.001579  0.001579  0.001579  0.003157
# 1    0.503571  0.688266  0.926633  1.109750  1.212358
# 2    0.014207  0.012629  0.011050  0.011050  0.009472
# 3    0.042622  0.039465  0.036308  0.033150  0.031572
# 4    0.137337  0.157859  0.172066  0.154702  0.170488
# ..        ...       ...       ...       ...       ...
# 195  0.011050  0.011050  0.009472  0.009472  0.007893
# 196  0.451477  0.607758  0.771931  0.838232  1.101857
# 197  0.102608  0.101030  0.086823  0.083665  0.061565
# 198  0.416748  0.514621  0.606179  0.674058  0.735624
# 199  0.009472  0.009472  0.009472  0.009472  0.007893
#
#                                                 Smiles
# 0    CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 1                            C[C@H]1[C@H](O1)P(=O)(O)O
# 2        C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 3        C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 4                      Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC
# ..                                                 ...
# 195      C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 196                                                NaN
# 197  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 198                                                NaN
# 199  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
#
# [200 rows x 12 columns]

# %%
well_and_plate_consistency = (
    df_control_growth_curves
    .groupby(['Compound', 'Concentration'])
    .agg(
        n_unique_wells=('Well', 'nunique'),
        
    )
)

# Filter to rows where there's more than one unique well
inconsistent_rows = well_and_plate_consistency[well_and_plate_consistency['n_unique_wells'] > 1]

# Display result
if inconsistent_rows.empty:
    print("All (Compound, Concentration) pairs are associated with a single Well and Plate_ID.")
else:
    print("The following (Compound, Concentration) pairs have inconsistencies:")
    print(inconsistent_rows)
# Out:
# The following (Compound, Concentration) pairs have inconsistencies:
#                              n_unique_wells
# Compound      Concentration
# Ciprofloxacin 0.200                       6
#               0.781                       6
#               1.200                       6
#               3.130                       6
#               7.900                       6
#               12.500                      6
#               50.000                      5
# DMSO          0.200                       6
#               0.781                       5
#               1.200                       5
#               3.130                       5
#               7.900                       6
#               12.500                      6
#               50.000                      4
# Fosfomycin    0.200                       6
#               0.781                       6
#               1.200                       3
#               3.130                       6
#               7.900                       6
#               12.500                      6
#               50.000                      6
# Rifampicin    0.200                       6
#               0.781                       5
#               1.200                       6
#               3.130                       6
#               7.900                       6
#               12.500                      6
#               50.000                      6
# Trimethoprim  0.200                       6
#               0.781                       6
#               1.200                       6
#               3.130                       6
#               7.900                       6
#               12.500                      6
#               50.000                      6

# %%
df_control_growth_curves = (
    df_control_growth_curves
    .groupby(['Compound','Concentration'], as_index=False)
    .agg({
        'Well': 'first',
        't_0': 'mean',
        't_2.08': 'mean',
        't_4.16': 'mean',
        't_6.24': 'mean',
        't_8.32': 'mean',
        't_10.4': 'mean',
        't_12.48': 'mean',
        'Smiles': 'first',
        
    })
)
df_control_growth_curves
# Out:
#          Compound  Concentration Well       t_0    t_2.08    t_4.16    t_6.24  \
# 0   Ciprofloxacin          0.200   J6  0.000000  0.083928  0.168646  0.177592
# 1   Ciprofloxacin          0.781  D21  0.000000  0.051830  0.097873  0.106555
# 2   Ciprofloxacin          1.200   D6  0.001052  0.042359  0.073668  0.074194
# 3   Ciprofloxacin          3.130   C8  0.000000  0.028152  0.038412  0.035255
# 4   Ciprofloxacin          7.900   C6  0.000000  0.009998  0.011839  0.011313
# 5   Ciprofloxacin         12.500  E19  0.000526  0.004473  0.004473  0.003683
# 6   Ciprofloxacin         50.000   D4  0.001894  0.001894  0.001894  0.001894
# 7            DMSO          0.200  F16  0.000000  0.123919  0.436217  0.571450
# 8            DMSO          0.781  H18  0.000000  0.126919  0.441058  0.548087
# 9            DMSO          1.200  C19  0.000000  0.117763  0.409171  0.550928
# 10           DMSO          3.130  E14  0.000000  0.133865  0.444216  0.586289
# 11           DMSO          7.900  D13  0.000000  0.130497  0.436217  0.567240
# 12           DMSO         12.500  I22  0.000000  0.123393  0.438848  0.568030
# 13           DMSO         50.000  F19  0.000000  0.127471  0.436480  0.582106
# 14     Fosfomycin          0.200   C4  0.000000  0.132075  0.453319  0.595655
# 15     Fosfomycin          0.781  C21  0.000000  0.129971  0.432534  0.555401
# 16     Fosfomycin          1.200  D20  0.000000  0.132602  0.437270  0.528302
# 17     Fosfomycin          3.130  D14  0.000263  0.075772  0.131812  0.078140
# 18     Fosfomycin          7.900  G10  0.007104  0.002105  0.002894  0.007367
# 19     Fosfomycin         12.500  C17  0.010261  0.002105  0.001842  0.002631
# 20     Fosfomycin         50.000  D12  0.011576  0.002368  0.002368  0.002368
# 21     Rifampicin          0.200  C22  0.000000  0.122867  0.424641  0.553296
# 22     Rifampicin          0.781  C15  0.000000  0.111764  0.383282  0.480207
# 23     Rifampicin          1.200  D17  0.000000  0.102345  0.305721  0.344922
# 24     Rifampicin          3.130  D15  0.000000  0.068669  0.112343  0.103398
# 25     Rifampicin          7.900  C18  0.000789  0.019469  0.020522  0.019206
# 26     Rifampicin         12.500   F9  0.000000  0.009735  0.009472  0.008682
# 27     Rifampicin         50.000   C3  0.005262  0.001052  0.000789  0.001315
# 28   Trimethoprim          0.200  C11  0.000000  0.125498  0.449372  0.586184
# 29   Trimethoprim          0.781  E11  0.000000  0.115763  0.424115  0.523566
# 30   Trimethoprim          1.200  C14  0.000526  0.105239  0.338871  0.411749
# 31   Trimethoprim          3.130   E5  0.000000  0.087612  0.241261  0.293355
# 32   Trimethoprim          7.900   D9  0.000000  0.082876  0.225739  0.271781
# 33   Trimethoprim         12.500  C16  0.000000  0.062881  0.198639  0.240209
# 34   Trimethoprim         50.000   C9  0.000000  0.028941  0.119973  0.155754
#
#       t_8.32    t_10.4   t_12.48  \
# 0   0.158912  0.143915  0.127077
# 1   0.104976  0.100241  0.093137
# 2   0.070510  0.066564  0.063144
# 3   0.032361  0.030256  0.027888
# 4   0.009998  0.009208  0.007893
# 5   0.003420  0.003157  0.002105
# 6   0.000947  0.000947  0.000316
# 7   0.701158  0.841126  0.959257
# 8   0.665534  0.788348  0.880854
# 9   0.662693  0.789611  0.916214
# 10  0.697106  0.832549  0.925054
# 11  0.705104  0.802714  0.930053
# 12  0.687740  0.823235  0.906375
# 13  0.706025  0.834680  0.937289
# 14  0.746937  0.869804  0.978200
# 15  0.640645  0.717996  0.770089
# 16  0.520935  0.791400  0.754567
# 17  0.026836  0.024994  0.027888
# 18  0.012366  0.020785  0.032098
# 19  0.003157  0.005262  0.007104
# 20  0.002105  0.002368  0.002631
# 21  0.639856  0.734834  0.800872
# 22  0.539247  0.555980  0.545561
# 23  0.351500  0.345711  0.335188
# 24  0.091558  0.082613  0.072878
# 25  0.018417  0.017365  0.016312
# 26  0.008156  0.007630  0.006841
# 27  0.001579  0.001579  0.002105
# 28  0.722732  0.857964  0.970307
# 29  0.616966  0.731940  0.832970
# 30  0.441742  0.483312  0.533564
# 31  0.306247  0.309141  0.308351
# 32  0.281779  0.280463  0.274938
# 33  0.242051  0.238630  0.231527
# 34  0.161016  0.150492  0.139442
#
#                                                Smiles
# 0       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 1       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 2       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 3       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 4       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 5       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 6       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                          C[C@H]1[C@H](O1)P(=O)(O)O
# 15                          C[C@H]1[C@H](O1)P(=O)(O)O
# 16                          C[C@H]1[C@H](O1)P(=O)(O)O
# 17                          C[C@H]1[C@H](O1)P(=O)(O)O
# 18                          C[C@H]1[C@H](O1)P(=O)(O)O
# 19                          C[C@H]1[C@H](O1)P(=O)(O)O
# 20                          C[C@H]1[C@H](O1)P(=O)(O)O
# 21  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 22  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 23  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 24  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 25  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 26  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 27  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...
# 28                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC
# 29                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC
# 30                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC
# 31                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC
# 32                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC
# 33                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC
# 34                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC

# %%
df_control_growth_curves["Control_Label"] = df_control_growth_curves["Compound"].apply(
    lambda x: -1 if x =='DMSO' else 1
)

df_control_growth_curves["Plate_ID"] = np.NaN

# %%
df_control_growth_curves["Well"] = df_control_growth_curves["Well"].str[0] + df_control_growth_curves["Well"].str[1:].str.zfill(2)

# %%
df_control_growth_curves
# Out:
#          Compound  Concentration Well       t_0    t_2.08    t_4.16    t_6.24  \
# 0   Ciprofloxacin          0.200  J06  0.000000  0.083928  0.168646  0.177592
# 1   Ciprofloxacin          0.781  D21  0.000000  0.051830  0.097873  0.106555
# 2   Ciprofloxacin          1.200  D06  0.001052  0.042359  0.073668  0.074194
# 3   Ciprofloxacin          3.130  C08  0.000000  0.028152  0.038412  0.035255
# 4   Ciprofloxacin          7.900  C06  0.000000  0.009998  0.011839  0.011313
# 5   Ciprofloxacin         12.500  E19  0.000526  0.004473  0.004473  0.003683
# 6   Ciprofloxacin         50.000  D04  0.001894  0.001894  0.001894  0.001894
# 7            DMSO          0.200  F16  0.000000  0.123919  0.436217  0.571450
# 8            DMSO          0.781  H18  0.000000  0.126919  0.441058  0.548087
# 9            DMSO          1.200  C19  0.000000  0.117763  0.409171  0.550928
# 10           DMSO          3.130  E14  0.000000  0.133865  0.444216  0.586289
# 11           DMSO          7.900  D13  0.000000  0.130497  0.436217  0.567240
# 12           DMSO         12.500  I22  0.000000  0.123393  0.438848  0.568030
# 13           DMSO         50.000  F19  0.000000  0.127471  0.436480  0.582106
# 14     Fosfomycin          0.200  C04  0.000000  0.132075  0.453319  0.595655
# 15     Fosfomycin          0.781  C21  0.000000  0.129971  0.432534  0.555401
# 16     Fosfomycin          1.200  D20  0.000000  0.132602  0.437270  0.528302
# 17     Fosfomycin          3.130  D14  0.000263  0.075772  0.131812  0.078140
# 18     Fosfomycin          7.900  G10  0.007104  0.002105  0.002894  0.007367
# 19     Fosfomycin         12.500  C17  0.010261  0.002105  0.001842  0.002631
# 20     Fosfomycin         50.000  D12  0.011576  0.002368  0.002368  0.002368
# 21     Rifampicin          0.200  C22  0.000000  0.122867  0.424641  0.553296
# 22     Rifampicin          0.781  C15  0.000000  0.111764  0.383282  0.480207
# 23     Rifampicin          1.200  D17  0.000000  0.102345  0.305721  0.344922
# 24     Rifampicin          3.130  D15  0.000000  0.068669  0.112343  0.103398
# 25     Rifampicin          7.900  C18  0.000789  0.019469  0.020522  0.019206
# 26     Rifampicin         12.500  F09  0.000000  0.009735  0.009472  0.008682
# 27     Rifampicin         50.000  C03  0.005262  0.001052  0.000789  0.001315
# 28   Trimethoprim          0.200  C11  0.000000  0.125498  0.449372  0.586184
# 29   Trimethoprim          0.781  E11  0.000000  0.115763  0.424115  0.523566
# 30   Trimethoprim          1.200  C14  0.000526  0.105239  0.338871  0.411749
# 31   Trimethoprim          3.130  E05  0.000000  0.087612  0.241261  0.293355
# 32   Trimethoprim          7.900  D09  0.000000  0.082876  0.225739  0.271781
# 33   Trimethoprim         12.500  C16  0.000000  0.062881  0.198639  0.240209
# 34   Trimethoprim         50.000  C09  0.000000  0.028941  0.119973  0.155754
#
#       t_8.32    t_10.4   t_12.48  \
# 0   0.158912  0.143915  0.127077
# 1   0.104976  0.100241  0.093137
# 2   0.070510  0.066564  0.063144
# 3   0.032361  0.030256  0.027888
# 4   0.009998  0.009208  0.007893
# 5   0.003420  0.003157  0.002105
# 6   0.000947  0.000947  0.000316
# 7   0.701158  0.841126  0.959257
# 8   0.665534  0.788348  0.880854
# 9   0.662693  0.789611  0.916214
# 10  0.697106  0.832549  0.925054
# 11  0.705104  0.802714  0.930053
# 12  0.687740  0.823235  0.906375
# 13  0.706025  0.834680  0.937289
# 14  0.746937  0.869804  0.978200
# 15  0.640645  0.717996  0.770089
# 16  0.520935  0.791400  0.754567
# 17  0.026836  0.024994  0.027888
# 18  0.012366  0.020785  0.032098
# 19  0.003157  0.005262  0.007104
# 20  0.002105  0.002368  0.002631
# 21  0.639856  0.734834  0.800872
# 22  0.539247  0.555980  0.545561
# 23  0.351500  0.345711  0.335188
# 24  0.091558  0.082613  0.072878
# 25  0.018417  0.017365  0.016312
# 26  0.008156  0.007630  0.006841
# 27  0.001579  0.001579  0.002105
# 28  0.722732  0.857964  0.970307
# 29  0.616966  0.731940  0.832970
# 30  0.441742  0.483312  0.533564
# 31  0.306247  0.309141  0.308351
# 32  0.281779  0.280463  0.274938
# 33  0.242051  0.238630  0.231527
# 34  0.161016  0.150492  0.139442
#
#                                                Smiles  Control_Label  Plate_ID
# 0       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O              1       NaN
# 1       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O              1       NaN
# 2       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O              1       NaN
# 3       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O              1       NaN
# 4       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O              1       NaN
# 5       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O              1       NaN
# 6       C1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O              1       NaN
# 7                                                None             -1       NaN
# 8                                                None             -1       NaN
# 9                                                None             -1       NaN
# 10                                               None             -1       NaN
# 11                                               None             -1       NaN
# 12                                               None             -1       NaN
# 13                                               None             -1       NaN
# 14                          C[C@H]1[C@H](O1)P(=O)(O)O              1       NaN
# 15                          C[C@H]1[C@H](O1)P(=O)(O)O              1       NaN
# 16                          C[C@H]1[C@H](O1)P(=O)(O)O              1       NaN
# 17                          C[C@H]1[C@H](O1)P(=O)(O)O              1       NaN
# 18                          C[C@H]1[C@H](O1)P(=O)(O)O              1       NaN
# 19                          C[C@H]1[C@H](O1)P(=O)(O)O              1       NaN
# 20                          C[C@H]1[C@H](O1)P(=O)(O)O              1       NaN
# 21  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...              1       NaN
# 22  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...              1       NaN
# 23  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...              1       NaN
# 24  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...              1       NaN
# 25  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...              1       NaN
# 26  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...              1       NaN
# 27  CN1CCN(CC1)/N=C/c2c(O)c3c5C(=O)[C@@]4(C)O/C=C/...              1       NaN
# 28                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC              1       NaN
# 29                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC              1       NaN
# 30                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC              1       NaN
# 31                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC              1       NaN
# 32                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC              1       NaN
# 33                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC              1       NaN
# 34                    Nc1nc(N)ncc1Cc(cc2OC)cc(OC)c2OC              1       NaN

# %% [markdown]
# # df_Enamine_DR_growthCurves

# %% [markdown]
# Enamine_DR_growthCurves has a subset of compounds in df_Enamine_t6_t12. Need to remove those rows from df_Enamine_t6_t12

# %%
df_Enamine_DR_growthCurves=pd.read_csv('/Users/ethankreuzer/Desktop/UdeM/MILA/Enamine_DR_growthcurves.csv')

#df_Enamine_DR_growthCurves['Concentration'].unique()
df_Enamine_DR_growthCurves['Concentration'].unique()
# Out:
# array([50.   , 12.5  ,  3.13 ,  0.781,  0.2  ])

# %%
df_Enamine_DR_growthCurves
# Out:
#      Well    Plate     Compound  Concentration Replicate  t_0    t_2.08  \
# 0     A03  111-DR1    Z27542156         50.000         D  0.0  0.130220
# 1     A04  111-DR1    Z27542156         12.500         D  0.0  0.171074
# 2     A05  111-DR1    Z27542156          3.130         D  0.0  0.181287
# 3     A06  111-DR1    Z27542156          0.781         D  0.0  0.194054
# 4     A07  111-DR1    Z27542156          0.200         D  0.0  0.194054
# ...   ...      ...          ...            ...       ...  ...       ...
# 2635  P03  111-DR9  Z6204188633         50.000         E  0.0  0.225165
# 2636  P04  111-DR9  Z6204188633         12.500         E  0.0  0.291691
# 2637  P05  111-DR9  Z6204188633          3.130         E  0.0  0.281456
# 2638  P06  111-DR9  Z6204188633          0.781         E  0.0  0.278897
# 2639  P07  111-DR9  Z6204188633          0.200         E  0.0  0.286573
#
#         t_4.16    t_6.24    t_8.32    t_10.4   t_12.48       MIC  \
# 0     0.434068  0.625569  0.732809  0.840049  0.947289  Inactive
# 1     0.518328  0.651102  0.778769  0.901329  1.018783  Inactive
# 2     0.543862  0.668975  0.801749  0.926863  1.039210  Inactive
# 3     0.556628  0.679189  0.804302  0.931969  1.039210  Inactive
# 4     0.571948  0.686849  0.814516  0.939629  1.049423  Inactive
# ...        ...       ...       ...       ...       ...       ...
# 2635  0.501503  0.624320  0.716433  0.790635  0.859720  Inactive
# 2636  0.614086  0.734344  0.857161  0.959509  1.056739  Inactive
# 2637  0.624320  0.762490  0.890424  1.000448  1.107913  Inactive
# 2638  0.647349  0.752255  0.895541  1.013241  1.123265  Inactive
# 2639  0.593616  0.739461  0.887865  1.013241  1.113030  Inactive
#
#                                                Smiles
# 0     [O-][N+](=O)C1=CC=C(S1)C(=O)NCC=2C=CC=3OCCOC3C2
# 1     [O-][N+](=O)C1=CC=C(S1)C(=O)NCC=2C=CC=3OCCOC3C2
# 2     [O-][N+](=O)C1=CC=C(S1)C(=O)NCC=2C=CC=3OCCOC3C2
# 3     [O-][N+](=O)C1=CC=C(S1)C(=O)NCC=2C=CC=3OCCOC3C2
# 4     [O-][N+](=O)C1=CC=C(S1)C(=O)NCC=2C=CC=3OCCOC3C2
# ...                                               ...
# 2635                NCC=1C=CC(OC=2C=CC(Cl)=CC2Cl)=CC1
# 2636                NCC=1C=CC(OC=2C=CC(Cl)=CC2Cl)=CC1
# 2637                NCC=1C=CC(OC=2C=CC(Cl)=CC2Cl)=CC1
# 2638                NCC=1C=CC(OC=2C=CC(Cl)=CC2Cl)=CC1
# 2639                NCC=1C=CC(OC=2C=CC(Cl)=CC2Cl)=CC1
#
# [2640 rows x 14 columns]

# %%
df_Enamine_DR_growthCurves[df_Enamine_DR_growthCurves['Compound'] == "Z1084007582"]
# Out:
#     Well    Plate     Compound  Concentration Replicate  t_0    t_2.08  \
# 215  K18  111-DR1  Z1084007582         50.000         D  0.0  0.183841
# 216  K19  111-DR1  Z1084007582         12.500         D  0.0  0.181287
# 217  K20  111-DR1  Z1084007582          3.130         D  0.0  0.176181
# 218  K21  111-DR1  Z1084007582          0.781         D  0.0  0.176181
# 219  K22  111-DR1  Z1084007582          0.200         D  0.0  0.178734
# 235  L18  111-DR1  Z1084007582         50.000         E  0.0  0.178734
# 236  L19  111-DR1  Z1084007582         12.500         E  0.0  0.183841
# 237  L20  111-DR1  Z1084007582          3.130         E  0.0  0.165967
# 238  L21  111-DR1  Z1084007582          0.781         E  0.0  0.188947
# 239  L22  111-DR1  Z1084007582          0.200         E  0.0  0.186394
#
#        t_4.16    t_6.24    t_8.32    t_10.4   t_12.48       MIC  \
# 215  0.492795  0.648549  0.781322  0.898776  1.011123  Inactive
# 216  0.505561  0.653655  0.771109  0.888563  0.993250  Inactive
# 217  0.518328  0.651102  0.760896  0.865583  0.970270  Inactive
# 218  0.515775  0.653655  0.760896  0.870689  0.975376  Inactive
# 219  0.543862  0.694509  0.817069  0.929416  1.031550  Inactive
# 235  0.533648  0.674082  0.799196  0.914096  1.021336  Inactive
# 236  0.518328  0.653655  0.773662  0.888563  0.995803  Inactive
# 237  0.510668  0.648549  0.755789  0.865583  0.965163  Inactive
# 238  0.525988  0.671529  0.791536  0.903883  1.008570  Inactive
# 239  0.538755  0.691955  0.809409  0.924309  1.028996  Inactive
#
#                                                Smiles
# 215  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 216  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 217  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 218  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 219  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 235  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 236  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 237  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 238  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2
# 239  [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2

# %% [markdown]
# We can see here that compounds at given concnetrations are at different wells for different Replicates

# %%
# Group by Compound and Concentration, then compute number of unique Wells and Plate_IDs
well_and_plate_consistency = (
    df_Enamine_DR_growthCurves
    .groupby(['Compound', 'Concentration'])
    .agg(
        n_unique_wells=('Well', 'nunique'),
        n_unique_plates=('Plate', 'nunique')
    )
)

# Filter to rows where there's more than one unique well
inconsistent_rows = well_and_plate_consistency[well_and_plate_consistency['n_unique_wells'] > 1]

# Display result
if inconsistent_rows.empty:
    print("All (Compound, Concentration) pairs are associated with a single Well and Plate_ID.")
else:
    print("The following (Compound, Concentration) pairs have inconsistencies:")
    print(inconsistent_rows)
# Out:
# The following (Compound, Concentration) pairs have inconsistencies:
#                            n_unique_wells  n_unique_plates
# Compound    Concentration
# Z1084007582 0.200                       2                1
#             0.781                       2                1
#             3.130                       2                1
#             12.500                      2                1
#             50.000                      2                1
# ...                                   ...              ...
# Z999961704  0.200                       2                1
#             0.781                       2                1
#             3.130                       2                1
#             12.500                      2                1
#             50.000                      2                1
#
# [1320 rows x 2 columns]

# %%
inconsistent_rows
# Out:
#                            n_unique_wells  n_unique_plates
# Compound    Concentration
# Z1084007582 0.200                       2                1
#             0.781                       2                1
#             3.130                       2                1
#             12.500                      2                1
#             50.000                      2                1
# ...                                   ...              ...
# Z999961704  0.200                       2                1
#             0.781                       2                1
#             3.130                       2                1
#             12.500                      2                1
#             50.000                      2                1
#
# [1320 rows x 2 columns]

# %%
df_Enamine_DR_growthCurves = (
    df_Enamine_DR_growthCurves
    .groupby(['Compound','Concentration'], as_index=False)
    .agg({
        'Well': 'first', #this is a shortcut becuase the replicates are in different wells
        't_0': 'mean',
        't_2.08': 'mean',
        't_4.16': 'mean',
        't_6.24': 'mean',
        't_8.32': 'mean',
        't_10.4': 'mean',
        't_12.48': 'mean',
        'Smiles': 'first',
        'Plate': 'first', #This is valid since all compound concentrations pairs are on the same plate
        'MIC': 'first' #this will get chnaged to control label
    })
)

# %%
df_Enamine_DR_growthCurves=df_Enamine_DR_growthCurves.rename(columns={"Plate": "Plate_ID","MIC":"Control_Label"}) #rename to be consistent with other compounds

df_Enamine_DR_growthCurves["Control_Label"] = 0 

df_Enamine_DR_compounds = df_Enamine_DR_growthCurves['Compound'].unique()

df_Enamine_DR_growthCurves
# Out:
#          Compound  Concentration Well  t_0    t_2.08    t_4.16    t_6.24  \
# 0     Z1084007582          0.200  K22  0.0  0.182564  0.541308  0.693232
# 1     Z1084007582          0.781  K21  0.0  0.182564  0.520882  0.662592
# 2     Z1084007582          3.130  K20  0.0  0.171074  0.514498  0.649825
# 3     Z1084007582         12.500  K19  0.0  0.182564  0.511945  0.653655
# 4     Z1084007582         50.000  K18  0.0  0.181287  0.513222  0.661315
# ...           ...            ...  ...  ...       ...       ...       ...
# 1315   Z999961704          0.200  A17  0.0  0.188947  0.536202  0.671529
# 1316   Z999961704          0.781  A16  0.0  0.191501  0.529818  0.657485
# 1317   Z999961704          3.130  A15  0.0  0.191501  0.536202  0.672805
# 1318   Z999961704         12.500  A14  0.0  0.191501  0.541308  0.666422
# 1319   Z999961704         50.000  A13  0.0  0.187671  0.547692  0.680465
#
#         t_8.32    t_10.4   t_12.48  \
# 0     0.813239  0.926863  1.030273
# 1     0.776216  0.887286  0.991973
# 2     0.758342  0.865583  0.967716
# 3     0.772386  0.888563  0.994526
# 4     0.790259  0.906436  1.016230
# ...        ...       ...       ...
# 1315  0.799196  0.917926  1.026443
# 1316  0.783876  0.900053  1.007293
# 1317  0.797919  0.914096  1.018783
# 1318  0.794089  0.914096  1.025166
# 1319  0.805579  0.926863  1.035380
#
#                                                  Smiles Plate_ID  \
# 0      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2  111-DR1
# 1      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2  111-DR1
# 2      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2  111-DR1
# 3      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2  111-DR1
# 4      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2  111-DR1
# ...                                                 ...      ...
# 1315  CC1=CC=C(C)N1C2CCN(CC2)C(=O)C3=C(C)OC(C)=C3S(=...  111-DR1
# 1316  CC1=CC=C(C)N1C2CCN(CC2)C(=O)C3=C(C)OC(C)=C3S(=...  111-DR1
# 1317  CC1=CC=C(C)N1C2CCN(CC2)C(=O)C3=C(C)OC(C)=C3S(=...  111-DR1
# 1318  CC1=CC=C(C)N1C2CCN(CC2)C(=O)C3=C(C)OC(C)=C3S(=...  111-DR1
# 1319  CC1=CC=C(C)N1C2CCN(CC2)C(=O)C3=C(C)OC(C)=C3S(=...  111-DR1
#
#       Control_Label
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 1315              0
# 1316              0
# 1317              0
# 1318              0
# 1319              0
#
# [1320 rows x 13 columns]

# %%
df_Enamine_DR_growthCurves['Well'].unique()
# Out:
# array(['K22', 'K21', 'K20', 'K19', 'K18', 'I12', 'I11', 'I10', 'I09',
#        'I08', 'A12', 'A11', 'A10', 'A09', 'A08', 'I22', 'I21', 'I20',
#        'I19', 'I18', 'C22', 'C21', 'C20', 'C19', 'C18', 'O22', 'O21',
#        'O20', 'O19', 'O18', 'M07', 'M06', 'M05', 'M04', 'M03', 'I07',
#        'I06', 'I05', 'I04', 'I03', 'E22', 'E21', 'E20', 'E19', 'E18',
#        'A07', 'A06', 'A05', 'A04', 'A03', 'C07', 'C06', 'C05', 'C04',
#        'C03', 'C12', 'C11', 'C10', 'C09', 'C08', 'C17', 'C16', 'C15',
#        'C14', 'C13', 'O12', 'O11', 'O10', 'O09', 'O08', 'E12', 'E11',
#        'E10', 'E09', 'E08', 'G22', 'G21', 'G20', 'G19', 'G18', 'M22',
#        'M21', 'M20', 'M19', 'M18', 'O17', 'O16', 'O15', 'O14', 'O13',
#        'A17', 'A16', 'A15', 'A14', 'A13', 'M12', 'M11', 'M10', 'M09',
#        'M08', 'G07', 'G06', 'G05', 'G04', 'G03', 'A22', 'A21', 'A20',
#        'A19', 'A18', 'O07', 'O06', 'O05', 'O04', 'O03', 'G17', 'G16',
#        'G15', 'G14', 'G13', 'G12', 'G11', 'G10', 'G09', 'G08', 'K12',
#        'K11', 'K10', 'K09', 'K08', 'E07', 'E06', 'E05', 'E04', 'E03',
#        'K07', 'K06', 'K05', 'K04', 'K03', 'I17', 'I16', 'I15', 'I14',
#        'I13', 'M17', 'M16', 'M15', 'M14', 'M13', 'E17', 'E16', 'E15',
#        'E14', 'E13', 'K17', 'K16', 'K15', 'K14', 'K13'], dtype=object)

# %% [markdown]
# Note down all the compounds in this dataframe and delete them in df_Enamine_t6_t12

# %% [markdown]
# # df_Enamine_t6_t12

# %%
df_Enamine_t6_t12_controls=pd.read_csv('/Users/ethankreuzer/Desktop/UdeM/MILA/Enamine_t6_t12_ctrls.csv')
df_Enamine_t6_t12_wells=pd.read_csv('/Users/ethankreuzer/Desktop/UdeM/MILA/Enamine_t6_t12_wells.csv')

# %%
well_and_plate_consistency = (
    df_Enamine_t6_t12_wells
    .groupby(['Compound'])
    .agg(
        n_unique_wells=('Well', 'nunique'),
        n_unique_plates=('Plate_ID', 'nunique')
    )
)

# Filter to rows where there's more than one unique well
inconsistent_rows = well_and_plate_consistency[well_and_plate_consistency['n_unique_wells'] > 1]

# Display result
if inconsistent_rows.empty:
    print("All (Compound, Concentration) pairs are associated with a single Well and Plate_ID.")
else:
    print("The following (Compound, Concentration) pairs have inconsistencies:")
    print(inconsistent_rows)

# %% [markdown]
# All compounds are tested on the same plate, but wells are inconsistent across replicates

# %%
well_and_plate_consistency = (
    df_Enamine_t6_t12_controls
    .groupby(['Compound'])
    .agg(
        n_unique_wells=('Well', 'nunique'),
        n_unique_plates=('Plate_ID', 'nunique')
    )
)

# Filter to rows where there's more than one unique well
inconsistent_rows = well_and_plate_consistency[well_and_plate_consistency['n_unique_wells'] > 1]

# Display result
if inconsistent_rows.empty:
    print("All (Compound, Concentration) pairs are associated with a single Well and Plate_ID.")
else:
    print("The following (Compound, Concentration) pairs have inconsistencies:")
    print(inconsistent_rows)

# %%
df_Enamine_t6_t12_wells
# Out:
#           Compound Replicate Well  t_0       t_6      t_12  \
# 0       Z839134902      OD_A  A03  0.0  0.564947  0.962840
# 1       Z965658782      OD_A  B03  0.0  0.692516  1.002325
# 2        Z16698707      OD_A  C03  0.0  0.534574  0.950691
# 3       Z952434162      OD_A  D03  0.0  0.586209  0.996251
# 4       Z558591178      OD_A  E03  0.0  0.574059  0.971952
# ...            ...       ...  ...  ...       ...       ...
# 63995  Z3342561431      OD_C  M05  0.0  0.523054  0.920575
# 63996  Z1459426305      OD_C  H15  0.0  0.538745  1.019955
# 63997  Z6191966153      OD_C  A05  0.0  0.564898  1.035647
# 63998  Z2396635673      OD_C  N17  0.0  0.533515  0.993802
# 63999  Z3019358249      OD_C  O11  0.0  0.682585  1.093183
#
#                                                   Smiles          Plate_ID  \
# 0              FC(F)(F)COC(=O)NC=1C=CC(=NC1)N2CCNC(=O)C2  1886318-Y12-A001
# 1      CC1=CC=C(S1)C=2C=CC(=O)N(CC=3C=CC=C([N+](=O)[O...  1886318-Y12-A001
# 2      CCN1C(SCC(=O)OCC=2C=CC(=CC2)[N+](=O)[O-])=NN=C...  1886318-Y12-A001
# 3      [O-][N+](=O)C=1C=CC(=CC1)C(=O)NC=2C=CC=C(C2)C=...  1886318-Y12-A001
# 4               CS(=O)(=O)NC1CCCN(C1)C(=O)NC2CCN3CCCCC23  1886318-Y12-A001
# ...                                                  ...               ...
# 63995       CC1(C)CN(CC1CN)C=2N=C(N=C3CCCC32)C=4C=CN=CC4  1886318-Y12-A100
# 63996                  CC(C)CCC1CCCCN1C(=O)C2=CSC(CN)=N2  1886318-Y12-A100
# 63997           CN1CCOC=2C=CC(=CC12)C(=O)NCC=3C=CC=NC3CN  1886318-Y12-A100
# 63998   CC1CC(CN1C(=O)NC=2C=C(C)C=C(CN)C2)C=3C=CC(C)=CC3  1886318-Y12-A100
# 63999    NCC=1C=CC2=NC(=CN2C1)C(=O)N3CCCC3C=4C=CC(F)=CC4  1886318-Y12-A100
#
#        Activity
# 0      Inactive
# 1      Inactive
# 2      Inactive
# 3      Inactive
# 4      Inactive
# ...         ...
# 63995  Inactive
# 63996  Inactive
# 63997  Inactive
# 63998  Inactive
# 63999  Inactive
#
# [64000 rows x 9 columns]

# %%
df_Enamine_t6_t12_controls
# Out:
#        Unnamed: 0 Well Replicate       Compound       t_0       t_6      t_12  \
# 0               1  A01      OD_A           DMSO  0.000000  0.584807  1.150336
# 1               2  A02      OD_A  Ciprofloxacin  0.003213  0.003213  0.000000
# 2               3  A23      OD_A           DMSO  0.000000  0.552675  1.098924
# 3               4  A24      OD_A           DMSO  0.000000  0.552675  1.111777
# 4               5  B01      OD_A           DMSO  0.000000  0.607300  1.137483
# ...           ...  ...       ...            ...       ...       ...       ...
# 12795       12796  O24      OD_C           DMSO  0.000000  0.604127  1.090567
# 12796       12797  P01      OD_C           DMSO  0.000000  0.708738  1.205639
# 12797       12798  P02      OD_C           DMSO  0.000000  0.632895  1.085337
# 12798       12799  P23      OD_C  Ciprofloxacin  0.000000  0.005231  0.002615
# 12799       12800  P24      OD_C           DMSO  0.000000  0.627665  1.161180
#
#                                              Smiles          Plate_ID  \
# 0                                               NaN  1886318-Y12-A081
# 1      1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O  1886318-Y12-A081
# 2                                               NaN  1886318-Y12-A081
# 3                                               NaN  1886318-Y12-A081
# 4                                               NaN  1886318-Y12-A081
# ...                                             ...               ...
# 12795                                           NaN  1886318-Y12-A100
# 12796                                           NaN  1886318-Y12-A100
# 12797                                           NaN  1886318-Y12-A100
# 12798  1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O  1886318-Y12-A100
# 12799                                           NaN  1886318-Y12-A100
#
#        Concentration
# 0                 50
# 1                 50
# 2                 50
# 3                 50
# 4                 50
# ...              ...
# 12795             50
# 12796             50
# 12797             50
# 12798             50
# 12799             50
#
# [12800 rows x 10 columns]

# %%
df_Enamine_t6_t12_wells = (
    df_Enamine_t6_t12_wells
    .groupby('Compound', as_index=False)
    .agg({
        'Well': 'first',
        'Plate_ID': 'first',
        't_0': 'mean',
        't_6': 'mean',
        't_12': 'mean',
        'Smiles': 'first',
        'Activity': 'first'
        
    })
)
df_Enamine_t6_t12_wells['Concentration'] = 50.0

df_Enamine_t6_t12_wells = df_Enamine_t6_t12_wells.rename(columns={"Activity":"Control_Label","t_6":"t_6.24", "t_12":"t_12.48"})

df_Enamine_t6_t12_wells['Control_Label'] = 0

# %%
df_Enamine_t6_t12_wells = df_Enamine_t6_t12_wells[~df_Enamine_t6_t12_wells["Compound"].isin(df_Enamine_DR_compounds)] #remove the compounds that are in DR, as 
#those are the only compounds we want

# %%
df_Enamine_t6_t12_wells
# Out:
#           Compound Well          Plate_ID  t_0    t_6.24   t_12.48  \
# 0      Z1000431776  L03  1886318-Y12-A082  0.0  0.464411  0.975276
# 1      Z1000729530  K14  1886318-Y12-A032  0.0  0.770719  0.923138
# 2      Z1001263652  F12  1886318-Y12-A014  0.0  0.861406  1.074267
# 3      Z1001363792  L12  1886318-Y12-A059  0.0  0.645117  0.984157
# 4      Z1001366686  D07  1886318-Y12-A051  0.0  0.603515  1.027211
# ...            ...  ...               ...  ...       ...       ...
# 31994   Z999074808  A11  1886318-Y12-A034  0.0  0.649522  1.012335
# 31995   Z999706442  G07  1886318-Y12-A085  0.0  0.485150  0.985027
# 31996   Z999855470  M21  1886318-Y12-A062  0.0  0.651710  1.058849
# 31997   Z999936250  M18  1886318-Y12-A032  0.0  0.694482  0.987004
# 31999   Z999961976  H12  1886318-Y12-A084  0.0  0.608119  1.034233
#
#                                                   Smiles  Control_Label  \
# 0             CC(C)COC(=O)N1CCCN(CC1)C(=O)C=2SC=CC2C3CC3              0
# 1          CC=1C=CC(OCCCNC(=O)C2=CC=C(O2)S(=O)(=O)N)=CC1              0
# 2      CC1=NOC=2N=CC(NC(=O)C=3C=CC=C(NS(=O)(=O)C)C3)=...              0
# 3               CCOC(=O)NCCC(=O)NCC(N1CCCC1)C2=CC=C(C)O2              0
# 4      CC1=CC=C(O1)C(CNC(=O)C=2C=CC=CC2[N+](=O)[O-])N...              0
# ...                                                  ...            ...
# 31994               CCOC(=O)NCCC(=O)N(CC1=CC=CO1)C2CCCC2              0
# 31995          CCOC(=O)NCCC(=O)NC(C)(C)C=1C=CC=2OCCOC2C1              0
# 31996     NC(=O)CC1CCCCN1C(=O)C=2C=CC(=CC2F)[N+](=O)[O-]              0
# 31997         CC(CC=1C=CC(=CC1)N(C)C)NC(=O)CCNS(=O)(=O)C              0
# 31999            CCOC(=O)NCCC(=O)N1CCC(CC1)N2C(C)=CC=C2C              0
#
#        Concentration
# 0               50.0
# 1               50.0
# 2               50.0
# 3               50.0
# 4               50.0
# ...              ...
# 31994           50.0
# 31995           50.0
# 31996           50.0
# 31997           50.0
# 31999           50.0
#
# [31736 rows x 9 columns]

# %%
df_Enamine_t6_t12_controls = (
    df_Enamine_t6_t12_controls
    .groupby(['Compound', 'Plate_ID'], as_index=False)
    .agg({
        #'Well': 'first', put NA for controls 
        #'Plate_ID': 'first', put NA for controls
        't_0': 'mean',
        't_6': 'mean',
        't_12': 'mean',
        'Smiles': 'first',
        'Concentration' : 'first'
    })
)

df_Enamine_t6_t12_controls = df_Enamine_t6_t12_controls.rename(columns={"t_6":"t_6.24", "t_12":"t_12.48"})


df_Enamine_t6_t12_controls ["Control_Label"] = df_Enamine_t6_t12_controls ["Compound"].apply(
    lambda x: 1 if x in ['Ciprofloxacin'] else (-1 if x == 'DMSO' else 0)
)
###No Activity Label here

# %%
df_Enamine_t6_t12_controls
# Out:
#           Compound          Plate_ID       t_0    t_6.24   t_12.48  \
# 0    Ciprofloxacin  1886318-Y12-A001  0.010702  0.012627  0.001626
# 1    Ciprofloxacin  1886318-Y12-A002  0.006508  0.004574  0.000689
# 2    Ciprofloxacin  1886318-Y12-A003  0.006387  0.005974  0.001443
# 3    Ciprofloxacin  1886318-Y12-A004  0.008978  0.004569  0.001390
# 4    Ciprofloxacin  1886318-Y12-A005  0.009662  0.004427  0.000395
# ..             ...               ...       ...       ...       ...
# 195           DMSO  1886318-Y12-A096  0.000000  0.590851  1.096532
# 196           DMSO  1886318-Y12-A097  0.000000  0.597467  1.089052
# 197           DMSO  1886318-Y12-A098  0.000000  0.606190  1.097033
# 198           DMSO  1886318-Y12-A099  0.000000  0.614978  1.098136
# 199           DMSO  1886318-Y12-A100  0.000000  0.621670  1.091351
#
#                                            Smiles  Concentration  \
# 0    1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O             50
# 1    1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O             50
# 2    1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O             50
# 3    1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O             50
# 4    1CNCCN1c(c2)c(F)cc3c2N(C4CC4)C=C(C3=O)C(=O)O             50
# ..                                            ...            ...
# 195                                          None             50
# 196                                          None             50
# 197                                          None             50
# 198                                          None             50
# 199                                          None             50
#
#      Control_Label
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 195             -1
# 196             -1
# 197             -1
# 198             -1
# 199             -1
#
# [200 rows x 8 columns]

# %% [markdown]
# # Combine into one df

# %%
#og = pd.read_pickle("/Users/ethankreuzer/Desktop/UdeM/MILA/GrowthCurve.pkl")
#og['Concentration'].unique()
# Out:
# array([50.  , 12.5 ,  3.13,  7.9 ,  0.2 ,  1.2 ])

# %%
df_control_growth_curves

# %%
df_Enamine_t6_t12_controls

# %%
comb_df = pd.concat([df_Enamine_DR_growthCurves, df_GrowthCurve_allData], ignore_index=True)

comb_df=pd.concat([comb_df, df_Enamine_t6_t12_wells], ignore_index=True)

comb_df=pd.concat([comb_df, df_control_growth_curves], ignore_index=True)

comb_df=pd.concat([comb_df, df_Enamine_t6_t12_controls], ignore_index=True)

#add df_Enamine_t6_t12_controls and add df_control_growth_curves

# %%
comb_df.columns
# Out:
# Index(['Compound', 'Concentration', 'Well', 't_0', 't_2.08', 't_4.16',
#        't_6.24', 't_8.32', 't_10.4', 't_12.48', 'Smiles', 'Plate_ID',
#        'Control_Label'],
#       dtype='object')

# %%
comb_df.to_pickle("/Users/ethankreuzer/Desktop/UdeM/MILA/GrowthCurve.pkl")

# %%
pd.read_pickle("/Users/ethankreuzer/Desktop/UdeM/MILA/GrowthCurve.pkl")
# Out:
#           Compound  Concentration Well  t_0    t_2.08    t_4.16    t_6.24  \
# 0      Z1084007582          0.200  K22  0.0  0.182564  0.541308  0.693232
# 1      Z1084007582          0.781  K21  0.0  0.182564  0.520882  0.662592
# 2      Z1084007582          3.130  K20  0.0  0.171074  0.514498  0.649825
# 3      Z1084007582         12.500  K19  0.0  0.182564  0.511945  0.653655
# 4      Z1084007582         50.000  K18  0.0  0.181287  0.513222  0.661315
# ...            ...            ...  ...  ...       ...       ...       ...
# 51718         DMSO         50.000  NaN  0.0       NaN       NaN  0.590851
# 51719         DMSO         50.000  NaN  0.0       NaN       NaN  0.597467
# 51720         DMSO         50.000  NaN  0.0       NaN       NaN  0.606190
# 51721         DMSO         50.000  NaN  0.0       NaN       NaN  0.614978
# 51722         DMSO         50.000  NaN  0.0       NaN       NaN  0.621670
#
#          t_8.32    t_10.4   t_12.48  \
# 0      0.813239  0.926863  1.030273
# 1      0.776216  0.887286  0.991973
# 2      0.758342  0.865583  0.967716
# 3      0.772386  0.888563  0.994526
# 4      0.790259  0.906436  1.016230
# ...         ...       ...       ...
# 51718       NaN       NaN  1.096532
# 51719       NaN       NaN  1.089052
# 51720       NaN       NaN  1.097033
# 51721       NaN       NaN  1.098136
# 51722       NaN       NaN  1.091351
#
#                                                  Smiles          Plate_ID  \
# 0      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2           111-DR1
# 1      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2           111-DR1
# 2      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2           111-DR1
# 3      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2           111-DR1
# 4      [O-][N+](=O)C=1C=CC=NC1SC2=NN=C(CC=3C=CC=CC3F)O2           111-DR1
# ...                                                 ...               ...
# 51718                                              None  1886318-Y12-A096
# 51719                                              None  1886318-Y12-A097
# 51720                                              None  1886318-Y12-A098
# 51721                                              None  1886318-Y12-A099
# 51722                                              None  1886318-Y12-A100
#
#        Control_Label
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 51718             -1
# 51719             -1
# 51720             -1
# 51721             -1
# 51722             -1
#
# [51723 rows x 13 columns]
